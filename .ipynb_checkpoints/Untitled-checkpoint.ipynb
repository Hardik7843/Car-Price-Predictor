# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
Y = df.Selling_Price

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
cat_feature = [col for col in df.columns if df[col].nunique() < 20]

# %%
cat_feature
# Out:
# ['Year', 'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# We are dropping the Car_Name feature as it dont play any important role in Math

# %%
df = df.drop(['Car_Name'] , axis = 1)

# %% [markdown]
# "no_of_year" tells how old the car is with respect to present year i.e 2023.

# %%
df['no_of_year'] = 2023 - df['Year']

# %%
df.drop(['Year'] , axis = 1 , inplace = True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0           3.35           5.59       27000    Petrol      Dealer  \
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_of_year
# 0       Manual      0           9
# 1       Manual      0          10
# 2       Manual      0           6
# 3       Manual      0          12
# 4       Manual      0           9

# %% [markdown]
# Here I have seperated the categorical columns from the dataset I have also droped 'Owner' as it is already binary feature so no need to do any encoding

# %%
cat_cols = [col for col in df.columns if df[col].nunique() < 5 ]
cat_df = df[cat_cols].drop(['Owner'], axis = 1)

# %%
cat_df.head()
# Out:
#   Fuel_Type Seller_Type Transmission
# 0    Petrol      Dealer       Manual
# 1    Diesel      Dealer       Manual
# 2    Petrol      Dealer       Manual
# 3    Petrol      Dealer       Manual
# 4    Diesel      Dealer       Manual

# %%
from sklearn.preprocessing import OneHotEncoder
OH_Enc = OneHotEncoder(drop = 'first' , max_categories = 3)

OH_Enc.fit(cat_df)
encoded_cat_df = pd.DataFrame(OH_Enc.transform(cat_df))

# %% [markdown]
# The problem will face during naming of encoded dataset since , I can type names of each columns for encoded date but in real practice it is not advisable as it can lead to human error. so I will now use inbuilt function of python for this.

# %%
encoded_df = pd.get_dummies(df , drop_first = True , dtype = 'int64')

# %%
encoded_df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_of_year
# 0           3.35           5.59       27000      0           9  \
# 1           4.75           9.54       43000      0          10
# 2           7.25           9.85        6900      0           6
# 3           2.85           4.15        5200      0          12
# 4           4.60           6.87       42450      0           9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual
# 0                 0                 1                       0  \
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0           3.35           5.59       27000    Petrol      Dealer  \
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_of_year
# 0       Manual      0           9
# 1       Manual      0          10
# 2       Manual      0           6
# 3       Manual      0          12
# 4       Manual      0           9

# %%
encoded_df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner
# Selling_Price                1.000000       0.876378    0.028566 -0.087880  \
# Present_Price                0.876378       1.000000    0.205253  0.009947
# Kms_Driven                   0.028566       0.205253    1.000000  0.089367
# Owner                       -0.087880       0.009947    0.089367  1.000000
# no_of_year                  -0.234369       0.053563    0.525714  0.181639
# Fuel_Type_Diesel             0.543541       0.464849    0.173295 -0.051836
# Fuel_Type_Petrol            -0.531636      -0.456746   -0.173595  0.054102
# Seller_Type_Individual      -0.553851      -0.511686   -0.101030  0.123646
# Transmission_Manual         -0.348869      -0.334265   -0.163881 -0.052166
#
#                         no_of_year  Fuel_Type_Diesel  Fuel_Type_Petrol
# Selling_Price            -0.234369          0.543541         -0.531636  \
# Present_Price             0.053563          0.464849         -0.456746
# Kms_Driven                0.525714          0.173295         -0.173595
# Owner                     0.181639         -0.051836          0.054102
# no_of_year                1.000000         -0.056469          0.052197
# Fuel_Type_Diesel         -0.056469          1.000000         -0.979104
# Fuel_Type_Petrol          0.052197         -0.979104          1.000000
# Seller_Type_Individual    0.036820         -0.345882          0.353865
# Transmission_Manual      -0.003434         -0.086264          0.078700
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.553851            -0.348869
# Present_Price                        -0.511686            -0.334265
# Kms_Driven                           -0.101030            -0.163881
# Owner                                 0.123646            -0.052166
# no_of_year                            0.036820            -0.003434
# Fuel_Type_Diesel                     -0.345882            -0.086264
# Fuel_Type_Petrol                      0.353865             0.078700
# Seller_Type_Individual                1.000000             0.058669
# Transmission_Manual                   0.058669             1.000000

# %%
sns.pairplot(encoded_df)

# %%
corrmat=encoded_df.corr()
corr_features=corrmat.columns

plt.figure(figsize=(20,20)) 
# #plot heat map
g=sns.heatmap(corrmat,annot=True,cmap="flag")

# %%
X = encoded_df.drop(['Selling_Price'], axis = 1)
y = encoded_df.Selling_Price

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no_of_year  Fuel_Type_Diesel
# 0           5.59       27000      0           9                 0  \
# 1           9.54       43000      0          10                 1
# 2           9.85        6900      0           6                 0
# 3           4.15        5200      0          12                 0
# 4           6.87       42450      0           9                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
#Feature Importance is used for Extracting importance feature
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.45039633, 0.040285  , 0.00080291, 0.08162616, 0.07949812,
#        0.02411795, 0.23430076, 0.08897277])

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# From this section I will be working on training of model

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , random_state = 69 , shuffle = True , test_size = 0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
model1 = RandomForestRegressor(n_estimators = 100 , random_state =69)
model1.fit(X_train , y_train)
y_pred1 = model1.predict(X_test)

# %%
plt.scatter( y_test, y_pred1 )
plt.xlabel('Actual')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
mae_model1 = mean_absolute_error(y_test , y_pred1)
mae_model1
# Out:
# 0.9389633333333341

# %%
X_train.shape
# Out:
# (239, 8)

# %%
X_test.shape
# Out:
# (60, 8)

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {'n_estimators':n_estimators , 
               'max_features':max_features , 
              'max_depth': max_depth ,
              'min_samples_split':min_samples_split ,
              'min_samples_leaf':min_samples_leaf }

# %%
rf = RandomForestRegressor()
model2 = RandomizedSearchCV( estimator = rf, param_distributions = random_grid , n_iter = 20, scoring='neg_root_mean_squared_error',cv=5,verbose=4)

# %%
model2.fit(X_train , y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 1/5] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=-2.143 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 2/5] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=-5.331 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 3/5] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=-1.967 total time=   0.1s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 4/5] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=-1.589 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 5/5] END max_depth=25, max_features=auto, min_samples_leaf=10, min_samples_split=10, n_estimators=300;, score=-1.611 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 1/5] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-3.014 total time=   0.3s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 2/5] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-4.199 total time=   0.4s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 3/5] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-1.540 total time=   0.3s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 4/5] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-1.162 total time=   0.3s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 5/5] END max_depth=30, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=500;, score=-1.199 total time=   0.3s
# [CV 1/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=-2.423 total time=   0.0s
# [CV 2/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=-5.877 total time=   0.0s
# [CV 3/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=-2.022 total time=   0.0s
# [CV 4/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=-2.012 total time=   0.0s
# [CV 5/5] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=100;, score=-1.371 total time=   0.0s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 1/5] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-2.573 total time=   0.5s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 2/5] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-4.202 total time=   0.5s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 3/5] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-1.238 total time=   0.5s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 4/5] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-0.924 total time=   0.5s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 5/5] END max_depth=15, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=600;, score=-0.877 total time=   0.5s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 1/5] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-2.835 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV 2/5] END max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=300;, score=-4.488 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV
_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15, n_estimators=500;, score=-1.571 total time=   0.3s
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-1.689 total time=   0.2s
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-4.607 total time=   0.2s
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-1.005 total time=   0.2s
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-1.767 total time=   0.2s
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300;, score=-0.731 total time=   0.2s
# C:\Users\hardi\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=20,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000]},
#                    scoring='neg_root_mean_squared_error', verbose=4)

# %%
y_pred2 = model2.predict(X_test)

# %%
sns.distplot(y_test-y_pred2)
# Out:
# C:\Users\hardi\AppData\Local\Temp\ipykernel_18240\2579743303.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred2)
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(y_test , y_pred2)
plt.xlabel('Actual')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
mae_model2 = mean_absolute_error(y_pred2 , y_test)
mae_model2
# Out:
# 0.9317930659571918

# %%
mae_model1
# Out:
# 0.9389633333333341

# %% [markdown]
# As observed above hyper parameter tuning performed good compared to **RandomForestRegressor**

# %%
from sklearn.linear_model import LinearRegression
model3 = LinearRegression()
model3.fit(X_train , y_train)
y_pred3 = model3.predict(X_test)
mae_model3 = mean_absolute_error(y_pred3 , y_test)

# %%
mae_model3
# Out:
# 1.1765481224170542

# %%
plt.scatter(y_test , y_pred3)
plt.xlabel('Actual')
plt.ylabel('Predictions')
# Out:
# Text(0, 0.5, 'Predictions')

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model2.pkl', 'wb')
# dump information to that file
pickle.dump(model2, file)

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.7.1
# numpy               1.24.3
# pandas              2.0.1
# scipy               1.10.1
# seaborn             0.12.2
# session_info        1.0.0
# sklearn             1.2.2
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.5.0
# asttokens           NA
# backcall            0.2.0
# cffi                1.15.1
# colorama            0.4.6
# comm                0.1.3
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.7
# decorator           5.1.1
# defusedxml          0.7.1
# executing           1.2.0
# importlib_metadata  NA
# importlib_resources NA
# ipykernel           6.23.1
# ipython_genutils    0.2.0
# ipywidgets          8.0.6
# jedi                0.18.2
# joblib              1.2.0
# kiwisolver          1.4.4
# matplotlib_inline   0.1.6
# mpl_toolkits        NA
# nt                  NA
# ntsecuritycon       NA
# packaging           23.1
# parso               0.8.3
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.5.1
# prompt_toolkit      3.0.38
# psutil              5.9.5
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.15.1
# pyparsing           3.0.9
# pythoncom           NA
# pytz                2023.3
# pywin32_bootstrap   NA
# pywin32_system32    NA
# pywintypes          NA
# six                 1.16.0
# stack_data          0.6.2
# threadpoolctl       3.1.0
# tornado             6.3.2
# traitlets           5.9.0
# typing_extensions   NA
# wcwidth             0.2.6
# win32api            NA
# win32com            NA
# win32security       NA
# zc                  NA
# zipp                NA
# zmq                 25.0.2
# zoneinfo            NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.13.2
# jupyter_client      8.2.0
# jupyter_core        5.3.0
# notebook            6.5.4
# -----
# Python 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)]
# Windows-10-10.0.22621-SP0
# -----
# Session information updated at 2023-06-14 23:34
# </pre>
# </details>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 pipreqsnb
#
# NameError: name 'pipreqsnb' is not defined
